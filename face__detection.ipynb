# %%
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def get_face_detection(imagePath,save_name="faces_detected.jpg"):
  image = cv2.imread(imagePath)
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
  faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30))
  print("[INFO] Found {0} Faces!".format(len(faces)))
  for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
  status = cv2.imwrite(save_name, image)

def show_img(img_name):
  image = cv2.imread(img_name)
  plt.imshow(image)

# %%
! wget https://images.firstpost.com/wp-content/uploads/2018/07/FRIENDS825_1.jpg
# Out:
# --2020-12-29 10:26:30--  https://images.firstpost.com/wp-content/uploads/2018/07/FRIENDS825_1.jpg
# Resolving images.firstpost.com (images.firstpost.com)... 23.12.145.35, 23.12.145.13, 2600:1408:20::172e:eee9, ...
# Connecting to images.firstpost.com (images.firstpost.com)|23.12.145.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 121862 (119K) [image/jpeg]
# Saving to: ‘FRIENDS825_1.jpg’
#
# FRIENDS825_1.jpg    100%[===================>] 119.01K   118KB/s    in 1.0s
#
# 2020-12-29 10:26:32 (118 KB/s) - ‘FRIENDS825_1.jpg’ saved [121862/121862]

# %%
get_face_detection('FRIENDS825_1.jpg','my_image.jpg') # 1.file path 2. which name file you want to save after face detect
# Out:
# [INFO] Found 6 Faces!

# %%
show_img('my_image.jpg')

# %%
! wget https://images.news18.com/ibnlive/uploads/2020/07/1595825471_untitled-design-11.jpg
# Out:
# --2020-12-29 10:42:25--  https://images.news18.com/ibnlive/uploads/2020/07/1595825471_untitled-design-11.jpg
# Resolving images.news18.com (images.news18.com)... 23.12.145.25, 23.12.145.6, 2600:1408:8c00::172e:9640, ...
# Connecting to images.news18.com (images.news18.com)|23.12.145.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52711 (51K) [image/jpeg]
# Saving to: ‘1595825471_untitled-design-11.jpg’
#
# 1595825471_untitled 100%[===================>]  51.48K   102KB/s    in 0.5s
#
# 2020-12-29 10:42:27 (102 KB/s) - ‘1595825471_untitled-design-11.jpg’ saved [52711/52711]

# %%
get_face_detection('1595825471_untitled-design-11.jpg','my_new_image.jpg')
# Out:
# [INFO] Found 5 Faces!

# %%
show_img('my_new_image.jpg')
